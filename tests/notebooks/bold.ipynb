# %%
from pathlib import Path

import nibabel as nib

import niftyone.image as noimg
from niftyone.figures.bold import carpet_plot, bold_mean_std

# %%
data_dir = Path("../data/ds000102")

func_path = data_dir / "sub-05" / "func" / "sub-05_task-flanker_run-2_bold.nii.gz"

# %%
func = nib.load(func_path)
func = noimg.to_iso_ras(func)

# %%
f = carpet_plot(func)

# %%
bold_mean_std(func)
# Out:
# <PIL.Image.Image image mode=RGB size=890x528>
