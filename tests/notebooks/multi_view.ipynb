# %%
from IPython.display import Video

from pathlib import Path

import nibabel as nib

from niftyone.multi_view import (
    three_view_frame,
    three_view_video,
    slice_video,
)

# %%
data_dir = Path("../data/ds000102")

anat_path = data_dir / "sub-01" / "anat" / "sub-01_T1w.nii.gz"
func_path = data_dir / "sub-01" / "func" / "sub-01_task-flanker_run-1_bold.nii.gz"

# %%
anat = nib.load(anat_path)
func = nib.load(func_path)

# %%
three_view_frame(anat)
# Out:
# <PIL.Image.Image image mode=RGB size=620x260>

# %%
three_view_frame(func)
# Out:
# <PIL.Image.Image image mode=RGB size=886x260>

# %%
three_view_video(func, "func.mp4")

Video("func.mp4")
# Out:
# <video src="func.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
slice_video(anat, "anat.mp4")

Video("anat.mp4")
# Out:
# <video src="anat.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
